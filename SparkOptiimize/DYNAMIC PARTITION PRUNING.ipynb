# %% [markdown]
# **Turn Off AQE, DPP & Autobroadcast**

# %%
spark.conf.set("spark.sql.adaptive.enabled","false")
spark.conf.set("spark.sql.optimizer.dynamicPartitionPruning.enabled","false")
spark.conf.set("spark.conf.autoBroadcastJoinThresold", -1)

from pyspark.sql.functions import *

# %% [markdown]
# **Read data**

# %%
df = spark.read.format("csv")\
            .option("header",True)\
            .option("inferSchema", True)\
            .load("/FileStore/rawdata/walmart.csv")


df = df.limit(100)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index</th><th>SHIPPING_LOCATION</th><th>DEPARTMENT</th><th>CATEGORY</th><th>SUBCATEGORY</th><th>BREADCRUMBS</th><th>SKU</th><th>PRODUCT_URL</th><th>PRODUCT_NAME</th><th>BRAND</th><th>PRICE_RETAIL</th><th>PRICE_CURRENT</th><th>PRODUCT_SIZE</th><th>PROMOTION</th><th>RunDate</th><th>tid</th></tr></thead><tbody><tr><td>1</td><td>79936</td><td>Deli</td><td>Hummus, Dips, & Salsa</td><td>null</td><td>Deli/Hummus, Dips, & Salsa</td><td>110895339</td><td>https://www.walmart.com/ip/Marketside-Roasted-Red-Pepper-Hummus-10-Oz/110895339?fulfillmentIntent=Pickup</td><td>Marketside Roasted Red Pepper Hummus, 10 Oz</td><td>Marketside</td><td>2.67</td><td>2.67</td><td>10</td><td>null</td><td>11-09-2022 21:20</td><td>16163804</td></tr><tr><td>2</td><td>79936</td><td>Deli</td><td>Hummus, Dips, & Salsa</td><td>null</td><td>Deli/Hummus, Dips, & Salsa</td><td>105455228</td><td>https://www.walmart.com/ip/Marketside-Roasted-Garlic-Hummus-10-Oz/105455228?fulfillmentIntent=Pickup</td><td>Marketside Roasted Garlic Hummus, 10 Oz</td><td>Marketside</td><td>2.67</td><td>2.67</td><td>10</td><td>null</td><td>11-09-2022 21:20</td><td>16163805</td></tr><tr><td>3</td><td>79936</td><td>Deli</td><td>Hummus, Dips, & Salsa</td><td>null</td><td>Deli/Hummus, Dips, & Salsa</td><td>128642379</td><td>https://www.walmart.com/ip/Marketside-Classic-Hummus-10-Oz/128642379?fulfillmentIntent=Pickup</td><td>Marketside Classic Hummus, 10 Oz</td><td>Marketside</td><td>2.67</td><td>2.67</td><td>10</td><td>null</td><td>11-09-2022 21:20</td><td>16163806</td></tr><tr><td>4</td><td>79936</td><td>Deli</td><td>Hummus, Dips, & Salsa</td><td>null</td><td>Deli/Hummus, Dips, & Salsa</td><td>366126367</td><td>https://www.walmart.com/ip/Marketside-Everything-Hummus-10-oz/366126367?fulfillmentIntent=Pickup</td><td>Marketside Everything Hummus, 10 oz</td><td>Marketside</td><td>2.67</td><td>2.67</td><td>10</td><td>null</td><td>11-09-2022 21:20</td><td>16163807</td></tr><tr><td>5</td><td>79936</td><td>Deli</td><td>Hummus, Dips, & Salsa</td><td>null</td><td>Deli/Hummus, Dips, & Salsa</td><td>160090316</td><td>https://www.walmart.com/ip/Price-s-Jalapeno-Dip-12-Oz/160090316?fulfillmentIntent=Pickup</td><td>Price's Jalapeno Dip, 12 Oz.</td><td>Price's</td><td>3.12</td><td>3.12</td><td>12</td><td>null</td><td>11-09-2022 21:20</td><td>16163808</td></tr><tr><td>6</td><td>79936</td><td>Deli</td><td>Hummus, Dips, & Salsa</td><td>null</td><td>Deli/Hummus, Dips, & Salsa</td><td>174071300</td><td>https://www.walmart.com/ip/Price-s-Green-Chili-Dip-12-Oz/174071300?fulfillmentIntent=Pickup</td><td>Price's Green Chili Dip, 12 Oz.</td><td>Price's</td><td>3.12</td><td>3.12</td><td>12</td><td>null</td><td>11-09-2022 21:20</td><td>16163809</td></tr><tr><td>7</td><td>48180</td><td>Beverages</td><td>Energy Drinks</td><td>null</td><td>Beverages/Energy Drinks</td><td>842388919</td><td>https://www.walmart.com/ip/Bang-Peach-Mango-Energy-Drink-with-Super-Creatine-16-oz-Can/842388919?fulfillmentIntent=Pickup&athbdg=L1600</td><td>Bang Peach Mango Energy Drink with Super Creatine, 16 oz Can</td><td>Bang</td><td>2.08</td><td>2.08</td><td>16</td><td>null</td><td>11-09-2022 21:20</td><td>16163910</td></tr><tr><td>8</td><td>48180</td><td>Beverages</td><td>Energy Drinks</td><td>null</td><td>Beverages/Energy Drinks</td><td>12018772</td><td>https://www.walmart.com/ip/Red-Bull-Energy-Drink-12-Fl-Oz/12018772?fulfillmentIntent=Pickup</td><td>Red Bull Energy Drink, 12 Fl Oz</td><td>Red Bull</td><td>2.68</td><td>2.68</td><td>12</td><td>null</td><td>11-09-2022 21:20</td><td>16163911</td></tr><tr><td>9</td><td>48180</td><td>Beverages</td><td>Energy Drinks</td><td>null</td><td>Beverages/Energy Drinks</td><td>12018770</td><td>https://www.walmart.com/ip/Red-Bull-Energy-Drink-Sugar-Free-8-4-Fl-Oz-4-Pack/12018770?fulfillmentIntent=Pickup</td><td>Red Bull Energy Drink, Sugar Free, 8.4 Fl Oz (4 Pack)</td><td>Red Bull</td><td>7.2 ...

# %% [markdown]
# **Preparing the partiton data**

# %%
df.write.format("parquet")\
        .mode("append")\
        .partitionBy("Department")\
        .option("path","/FileStore/rawdata/dpp_partioned")\
        .save()

# %% [markdown]
# **Non Partitioned Data**

# %%
df.write.format("parquet")\
        .mode("append")\
        .option("path","/FileStore/rawdata/dpp_nonpartioned")\
        .save()

# %% [markdown]
# **Dataframes**

# %%
df1 = spark.read.format("parquet")\
        .load("/FileStore/rawdata/dpp_partioned")

# %%
df2 = spark.read.format("parquet")\
        .load("/FileStore/rawdata/dpp_nonpartioned")

# %% [markdown]
# **JOINS**

# %%
df_joins = df1.join(df2.filter(col("Department")=="Beverages"), df1['tid']== df2['tid'], "inner")

# %%
df_joins.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index</th><th>SHIPPING_LOCATION</th><th>CATEGORY</th><th>SUBCATEGORY</th><th>BREADCRUMBS</th><th>SKU</th><th>PRODUCT_URL</th><th>PRODUCT_NAME</th><th>BRAND</th><th>PRICE_RETAIL</th><th>PRICE_CURRENT</th><th>PRODUCT_SIZE</th><th>PROMOTION</th><th>RunDate</th><th>tid</th><th>Department</th><th>index</th><th>SHIPPING_LOCATION</th><th>DEPARTMENT</th><th>CATEGORY</th><th>SUBCATEGORY</th><th>BREADCRUMBS</th><th>SKU</th><th>PRODUCT_URL</th><th>PRODUCT_NAME</th><th>BRAND</th><th>PRICE_RETAIL</th><th>PRICE_CURRENT</th><th>PRODUCT_SIZE</th><th>PROMOTION</th><th>RunDate</th><th>tid</th></tr></thead><tbody><tr><td>7</td><td>48180</td><td>Energy Drinks</td><td>null</td><td>Beverages/Energy Drinks</td><td
td><td>Energy Drinks</td><td>null</td><td>Beverages/Energy Drinks</td><td>19766232</td><td>https://www.walmart.com/ip/V8-ENERGY-Pomegranate-Blueberry-Energy-Drink-8-FL-OZ-Can-Pack-of-6/19766232?fulfillmentIntent=Pickup</td><td>V8 +ENERGY Pomegranate Blueberry Energy Drink, 8 FL OZ Can (Pack of 6)</td><td>V8</td><td>5.14</td><td>5.14</td><td>8</td><td>null</td><td>11-09-2022 21:20</td><td>16163913</td><td>Beverages</td><td>10</td><td>48180</td><td>Beverages</td><td>Energy Drinks</td><td>null</td><td>Beverages/Energy Drinks</td><td>19766232</td><td>https://www.walmart.com/ip/V8-ENERGY-Pomegranate-Blueberry-Energy-Drink-8-FL-OZ-Can-Pack-of-6/19766232?fulfillmentIntent=Pickup</td><td>V8 +ENERGY Pomegranate Blueberry Energy Drink, 8 FL OZ Can (Pack  ...

# %% [markdown]
# **Turn ON AQE, DPP & Autobroadcast**

# %%
spark.conf.set("spark.sql.adaptive.enabled","true")
spark.conf.set("spark.sql.optimizer.dynamicPartitionPruning.enabled","true")
spark.conf.set("spark.conf.autoBroadcastJoinThresold", 5 * 1024 * 1024)

from pyspark.sql.functions import *

# %%
df.write.format("parquet")\
        .mode("append")\
        .partitionBy("tid")\
        .option("path","/FileStore/rawdata/dpp_partioneNew")\
        .save()

# %%
df1 = spark.read.format("parquet")\
        .load("/FileStore/rawdata/dpp_partioneNew")

# %%
df2 = spark.read.format("parquet")\
        .load("/FileStore/rawdata/dpp_nonpartioned")

# %%
df_joins = df1.join(df2.filter(col("tid")=="16164408"), df1['tid']== df2['tid'], "inner")

# %%
df_joins.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index</th><th>SHIPPING_LOCATION</th><th>DEPARTMENT</th><th>CATEGORY</th><th>SUBCATEGORY</th><th>BREADCRUMBS</th><th>SKU</th><th>PRODUCT_URL</th><th>PRODUCT_NAME</th><th>BRAND</th><th>PRICE_RETAIL</th><th>PRICE_CURRENT</th><th>PRODUCT_SIZE</th><th>PROMOTION</th><th>RunDate</th><th>tid</th><th>index</th><th>SHIPPING_LOCATION</th><th>DEPARTMENT</th><th>CATEGORY</th><th>SUBCATEGORY</th><th>BREADCRUMBS</th><th>SKU</th><th>PRODUCT_URL</th><th>PRODUCT_NAME</th><th>BRAND</th><th>PRICE_RETAIL</th><th>PRICE_CURRENT</th><th>PRODUCT_SIZE</th><th>PROMOTION</th><th>RunDate</th><th>tid</th></tr></thead><tbody><tr><td>100</td><td>48180</td><td>Beverages</td><td>Sparkling Water</td><td>null</td><td>Beverages/Sparkling Water</td><td>734386776</td><td>https://www.walmart.com/ip/Clear-American-Sparkling-Water-Cherry-Vanilla-33-8-fl-oz/734386776?fulfillmentIntent=Pickup</td><td>Clear American Sparkling Water, Cherry Vanilla, 33.8 fl oz</td><td>Clear American</td><td>0.7</td><td>0.7</td><td>33.8</td><td>null</td><td>11-09-2022 21:20</td><td>16164408</td><td>100</td><td>48180</td><td>Beverages</td><td>Sparkling Water</td><td>null</td><td>Beverages/Sparkling Water</td><td>734386776</td><td>https://www.walmart.com/ip/Clear-American-Sparkling-Water-Cherry-Vanilla-33-8-fl-oz/734386776?fulfillmentIntent=Pickup</td><td>Clear American Sparkling Water, Cherry Vanilla, 33.8 fl oz</td><td>Clear American</td><td>0.7</td><td>0.7</td><td>33.8</td><td>null</td><td>11-09-2022 21:20</td><td>16164408</td></tr></tbody></table></div>
